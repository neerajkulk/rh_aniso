# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %% [markdown]
# # Do the txt RH outputs work?

# %%
sr_lambda  = np.loadtxt('wl.csv')

# %%
plt.plot(np.gradient(sr_lambda)>0.1)

# %%
plt.plot(sr_lambda[11:62])

# %%
sr_lambda[61]
# Out:
# 461.1167958137845

# %%
sr_lambda[11]
# Out:
# 460.7325805069672

# %%
plt.plot(sr_lambda[11:61])

# %%
plt.plot(np.gradient(sr_lambda[11:61]))

# %%
sr_lambda[11]
# Out:
# 460.7325805069672

# %%
sr_lambda[61]
# Out:
# 461.1167958137845

# %%
J00 = np.loadtxt('J.txt').reshape(82,4,4)
J20 = np.loadtxt('J20.txt').reshape(82,4,4)
reJ21 = np.loadtxt('reJ21.txt').reshape(82,4,4)
imJ21 = np.loadtxt('imJ21.txt').reshape(82,4,4)
reJ22 = np.loadtxt('reJ22.txt').reshape(82,4,4)
imJ22 = np.loadtxt('imJ22.txt').reshape(82,4,4)

# %%
plt.imshow(imJ21[30,:,:]/J00[30,:,:],cmap='bwr')
plt.colorbar()

# %%
np.min(reJ22)
# Out:
# 8.578585178e-11

# %%
np.max(reJ22)
# Out:
# 7.84248905912e-09

# %%
plt.hist(reJ22[30,:,:]*1e11)
# Out:
# ([array([4., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 2.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 2.]),
#   array([4., 0., 0., 0., 0., 0., 0., 0., 0., 0.])],
#  array([8.59139286, 8.59141741, 8.59144196, 8.59146651, 8.59149106,
#         8.5915156 , 8.59154015, 8.5915647 , 8.59158925, 8.5916138 ,
#         8.59163834]),
#  <a list of 4 Lists of Patches objects>)

# %%
plt.imshow(J20[30,:,:]/J00[30,:,:],cmap='bwr')
plt.colorbar()

# %%
J20
# Out:
# array([[[7.5200e-18, 7.6400e-18, 7.6400e-18, 7.5200e-18],
#         [7.6400e-18, 7.5100e-18, 7.5100e-18, 7.6400e-18],
#         [7.6400e-18, 7.5100e-18, 7.5100e-18, 7.6400e-18],
#         [7.5200e-18, 7.6400e-18, 7.6400e-18, 7.5200e-18]],
#
#        [[7.5900e-18, 7.7100e-18, 7.7100e-18, 7.5900e-18],
#         [7.7100e-18, 7.5900e-18, 7.5900e-18, 7.7100e-18],
#         [7.7100e-18, 7.5900e-18, 7.5900e-18, 7.7100e-18],
#         [7.5900e-18, 7.7100e-18, 7.7100e-18, 7.5900e-18]],
#
#        [[7.6600e-18, 7.7800e-18, 7.7800e-18, 7.6600e-18],
#         [7.7800e-18, 7.6700e-18, 7.6700e-18, 7.7800e-18],
#         [7.7800e-18, 7.6700e-18, 7.6700e-18, 7.7800e-18],
#         [7.6600e-18, 7.7800e-18, 7.7800e-18, 7.6600e-18]],
#
#        ...,
#
#        [[8.4270e-17, 8.4890e-17, 8.4890e-17, 8.4270e-17],
#         [8.4890e-17, 2.1922e-16, 2.1922e-16, 8.4890e-17],
#         [8.4890e-17, 2.1922e-16, 2.1922e-16, 8.4890e-17],
#         [8.4270e-17, 8.4890e-17, 8.4890e-17, 8.4270e-17]],
#
# ...

# %%
plt.imshow(J20[3,:,:])

# %%
for i in np.arange(82):
    plt.imshow(J00[i,:,:],cmap='inferno')
    plt.colorbar()
    plt.show()

# %%
plt.imshow(J20[60,:,:],cmap='bwr')
plt.colorbar()

# %%
plt.imshow(reJ21[30,:,:]/J00[30,:,:],cmap='bwr')
plt.colorbar()

# %%
plt.imshow(imJ21[30,:,:]/J00[30,:,:],cmap='bwr')
plt.colorbar()

# %%
plt.imshow(reJ22[30,:,:]/J00[30,:,:],cmap='bwr')
plt.colorbar()

# %%
plt.imshow(imJ22[30,:,:]/J00[30,:,:],cmap='bwr')
plt.colorbar()

# %% [markdown]
# # Reading in a binary file

# %%
#dt      = np.dtype("i4, (3)f8")
binJ20 = np.fromfile('testJ20.data',dtype = 'double', count = -1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-237ad1c717ae> in <module>
#       1 #dt      = np.dtype("i4, (3)f8")
# ----> 2 binJ20 = np.fromfile('testJ20.data',dtype = 'double', count = -1)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testJ20.data'

# %%
binJ20
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-37fae25fbd50> in <module>
# ----> 1 binJ20
#
# NameError: name 'binJ20' is not defined
